# %%
ls
# Out:
# sample_data/

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd My Drive/Colab Notebooks
# Out:
# [Errno 2] No such file or directory: 'My Drive/Colab Notebooks'
# /content

# %%
cd tt-pytorch/sentiment
# Out:
# /content/gdrive/My Drive/Colab Notebooks/tt-pytorch/sentiment

# %%
ls
# Out:
# build/  dist/  README.md  sentiment/  setup.py  t3nsor/  t3nsor.egg-info/

# %%
cd ..
# Out:
# /content/gdrive/My Drive/Colab Notebooks/tt-pytorch

# %%
! python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# writing t3nsor.egg-info/PKG-INFO
# writing dependency_links to t3nsor.egg-info/dependency_links.txt
# writing requirements to t3nsor.egg-info/requires.txt
# writing top-level names to t3nsor.egg-info/top_level.txt
# reading manifest file 't3nsor.egg-info/SOURCES.txt'
# writing manifest file 't3nsor.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/t3nsor
# copying build/lib/t3nsor/decompositions.py -> build/bdist.linux-x86_64/egg/t3nsor
# copying build/lib/t3nsor/__init__.py -> build/bdist.linux-x86_64/egg/t3nsor
# copying build/lib/t3nsor/initializers_tr.py -> build/bdist.linux-x86_64/egg/t3nsor
# copying build/lib/t3nsor/initializers.py -> build/bdist.linux-x86_64/egg/t3nsor
# copying build/lib/t3nsor/ops.py -> build/bdist.linux-x86_64/egg/t3nsor
# ...

# %%
cd sentiment
# Out:
# /content/gdrive/My Drive/Colab Notebooks/tt-pytorch/sentiment

# %%
! python train.py --gpu=0 --embed_dim=256 --dataset=imdb --n_epochs=100 --embedding=tr --d=3 --ranks=16
# Out:
# Building dataset...
# Done
# Traceback (most recent call last):
#   File "train.py", line 131, in <module>
#     embed_model = t3.TREmbedding(
# AttributeError: module 't3nsor' has no attribute 'TREmbedding'
